# %%
import numpy as np      
import matplotlib.pyplot as plt                      
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(0) 
X=2*np.random.rand(100,1) 
y=3*X**2 + 2*X + 1 + np.random.rand(100,1)

# %%
plt.scatter(X,y,color="pink",label="Real Data") 
plt.title("Dataset with Quadratic Equations") 
plt.xlabel("X") 
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
poly_feature= PolynomialFeatures(degree=2)  
X_poly = poly_feature.fit_transform(X)

# %%
model = LinearRegression()

# %%
model.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
X_new = np.linspace(0,2,100).reshape(-1,1)
X_new_poly = poly_feature.transform(X_new)
y_new = model.predict(X_new_poly)

# %%
plt.scatter(X,y,color="pink", label="Real Data")
plt.plot(X_new,y_new,color="red", label="Poly Data")
plt.title("Poly Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
